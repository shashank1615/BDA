# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import EarlyStopping

# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Define EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=5,  # Number of epochs with no improvement after which training will be stopped
                               restore_best_weights=True)  # Restores model to best weights with the lowest validation loss

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
autoencoder.fit(x_train, x_train,  # For autoencoders, input and output are the same
                epochs=100,  # Set a high number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[early_stopping])  # Add the early stopping callback
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.4344 - val_loss: 0.2346
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2299 - val_loss: 0.2090
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2032 - val_loss: 0.1852
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.1840 - val_loss: 0.1765
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1764 - val_loss: 0.1709
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1713 - val_loss: 0.1685
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1690 - val_loss: 0.1657
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1665 - val_loss: 0.1636
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1643 - val_loss: 0.1612
# Epoch 10/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1615 - val_loss: 0.1584
# Epoch 11/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1590 - val_loss: 0.1559
# Epoch 12/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1568 - val_loss: 0.1540
# Epoch 13/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1549 - val_loss: 0.1525
# Epoch 14/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1529 - val_loss: 0.1511
# Epoch 15/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1519 - val_loss: 0.1500
# Epoch 16/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1511 - val_loss: 0.1493
# Epoch 17/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1499 - val_loss: 0.1484
# Epoch 18/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1493 - val_loss: 0.1478
# Epoch 19/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1492 - val_loss: 0.1473
# Epoch 20/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1483 - val_loss: 0.1467
# Epoch 21/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1478 - val_loss: 0.1454
# Epoch 22/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1464 - val_loss: 0.1445
# Epoch 23/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1453 - val_loss: 0.1435
# Epoch 24/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1445 - val_loss: 0.1428
# Epoch 25/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1442 - val_loss: 0.1423
# Epoch 26/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1431 - val_loss: 0.1417
# Epoch 27/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1429 - val_loss: 0.1409
# Epoch 28/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1422 - val_loss: 0.1403
# Epoch 29/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1415 - val_loss: 0.1398
# Epoch 30/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1409 - val_loss: 0.1393
# Epoch 31/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1404 - val_loss: 0.1390
# Epoch 32/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1405 - val_loss: 0.1388
# Epoch 33/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1405 - val_loss: 0.1388
# Epoch 34/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1402 - val_loss: 0.1384
# Epoch 35/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1396 - val_loss: 0.1383
# Epoch 36/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1399 - val_loss: 0.1382
# Epoch 37/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1399 - val_loss: 0.1381
# Epoch 38/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1394 - val_loss: 0.1380
# Epoch 39/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1394 - val_loss: 0.1378
# Epoch 40/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1391 - val_loss: 0.1380
# Epoch 41/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1392 - val_loss: 0.1377
# Epoch 42/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1393 - val_loss: 0.1377
# Epoch 43/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1394 - val_loss: 0.1377
# Epoch 44/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1390 - val_loss: 0.1377
# Epoch 45/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1394 - val_loss: 0.1376
# Epoch 46/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1388 - val_loss: 0.1375
# Epoch 47/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1389 - val_loss: 0.1374
# Epoch 48/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1389 - val_loss: 0.1374
# Epoch 49/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1387 - val_loss: 0.1374
# Epoch 50/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1389 - val_loss: 0.1374
# Epoch 51/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1390 - val_loss: 0.1373
# Epoch 52/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1391 - val_loss: 0.1374
# Epoch 53/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1390 - val_loss: 0.1374
# Epoch 54/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1388 - val_loss: 0.1373
# Epoch 55/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1389 - val_loss: 0.1373
# Epoch 56/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1388 - val_loss: 0.1374
# Epoch 57/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1388 - val_loss: 0.1372
# Epoch 58/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1389 - val_loss: 0.1371
# Epoch 59/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1387 - val_loss: 0.1372
# Epoch 60/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1389 - val_loss: 0.1371
# Epoch 61/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1388 - val_loss: 0.1370
# Epoch 62/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1388 - val_loss: 0.1371
# Epoch 63/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1387 - val_loss: 0.1371
# Epoch 64/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1386 - val_loss: 0.1372
# Epoch 65/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1386 - val_loss: 0.1371
# Epoch 66/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1387 - val_loss: 0.1372

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import TerminateOnNaN

# Define the TerminateOnNaN callback
terminate_on_nan = TerminateOnNaN()

# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
# Assuming x_train and x_test are your training and validation datasets
autoencoder.fit(x_train, x_train,  # For autoencoders, input and output are the same
                epochs=30,  # Set the number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[terminate_on_nan])  # Add the TerminateOnNaN callback
# Out:
# Epoch 1/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.4430 - val_loss: 0.2358
# Epoch 2/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2248 - val_loss: 0.1994
# Epoch 3/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1955 - val_loss: 0.1806
# Epoch 4/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1801 - val_loss: 0.1742
# Epoch 5/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1745 - val_loss: 0.1681
# Epoch 6/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1681 - val_loss: 0.1621
# Epoch 7/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1628 - val_loss: 0.1588
# Epoch 8/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1597 - val_loss: 0.1561
# Epoch 9/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1568 - val_loss: 0.1539
# Epoch 10/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1549 - val_loss: 0.1520
# Epoch 11/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1528 - val_loss: 0.1498
# Epoch 12/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1504 - val_loss: 0.1480
# Epoch 13/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1489 - val_loss: 0.1468
# Epoch 14/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1479 - val_loss: 0.1460
# Epoch 15/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.1476 - val_loss: 0.1453
# Epoch 16/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1469 - val_loss: 0.1448
# Epoch 17/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1460 - val_loss: 0.1442
# Epoch 18/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1454 - val_loss: 0.1438
# Epoch 19/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.1453 - val_loss: 0.1435
# Epoch 20/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1445 - val_loss: 0.1433
# Epoch 21/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1445 - val_loss: 0.1430
# Epoch 22/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1446 - val_loss: 0.1428
# Epoch 23/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1442 - val_loss: 0.1426
# Epoch 24/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.1442 - val_loss: 0.1423
# Epoch 25/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1436 - val_loss: 0.1422
# Epoch 26/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1436 - val_loss: 0.1419
# Epoch 27/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1431 - val_loss: 0.1417
# Epoch 28/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1433 - val_loss: 0.1418
# Epoch 29/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1434 - val_loss: 0.1415
# Epoch 30/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1426 - val_loss: 0.1414

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the ModelCheckpoint callback
checkpoint = ModelCheckpoint(filepath='autoencoder_best.keras',  # File path to save the model
                             monitor='val_loss',  # Metric to monitor
                             save_best_only=True,  # Save only the best model (based on the monitored metric)
                             mode='min',  # Minimize the monitored metric (e.g., validation loss)
                             save_weights_only=False,  # Save the entire model (set to True to save only weights)
                             verbose=1)  # Print a message when saving the model


# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
# Assuming x_train and x_test are your training and validation datasets
autoencoder.fit(x_train, x_train,  # For autoencoders, input and output are the same
                epochs=30,  # Number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),  # Validation data
                callbacks=[checkpoint])  # Add the ModelCheckpoint callback
# Out:
# Epoch 1/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4266
# Epoch 1: val_loss improved from inf to 0.23872, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.4252 - val_loss: 0.2387
# Epoch 2/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2274
# Epoch 2: val_loss improved from 0.23872 to 0.19719, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.2271 - val_loss: 0.1972
# Epoch 3/30
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1912
# Epoch 3: val_loss improved from 0.19719 to 0.17481, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1910 - val_loss: 0.1748
# Epoch 4/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1748
# Epoch 4: val_loss improved from 0.17481 to 0.16954, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1748 - val_loss: 0.1695
# Epoch 5/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1692
# Epoch 5: val_loss improved from 0.16954 to 0.16123, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1691 - val_loss: 0.1612
# Epoch 6/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1615
# Epoch 6: val_loss improved from 0.16123 to 0.15663, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1614 - val_loss: 0.1566
# Epoch 7/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1579
# Epoch 7: val_loss improved from 0.15663 to 0.15490, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1579 - val_loss: 0.1549
# Epoch 8/30
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1561
# Epoch 8: val_loss improved from 0.15490 to 0.15396, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1561 - val_loss: 0.1540
# Epoch 9/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1552
# Epoch 9: val_loss improved from 0.15396 to 0.15342, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1552 - val_loss: 0.1534
# Epoch 10/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1547
# Epoch 10: val_loss improved from 0.15342 to 0.15280, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1547 - val_loss: 0.1528
# Epoch 11/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1541
# Epoch 11: val_loss improved from 0.15280 to 0.15223, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.1541 - val_loss: 0.1522
# Epoch 12/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1535
# Epoch 12: val_loss improved from 0.15223 to 0.15167, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1535 - val_loss: 0.1517
# Epoch 13/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1533
# Epoch 13: val_loss improved from 0.15167 to 0.15072, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1533 - val_loss: 0.1507
# Epoch 14/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1522
# Epoch 14: val_loss improved from 0.15072 to 0.15011, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1522 - val_loss: 0.1501
# Epoch 15/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1514
# Epoch 15: val_loss improved from 0.15011 to 0.14921, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1514 - val_loss: 0.1492
# Epoch 16/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1509
# Epoch 16: val_loss improved from 0.14921 to 0.14856, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1509 - val_loss: 0.1486
# Epoch 17/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1497
# Epoch 17: val_loss improved from 0.14856 to 0.14777, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1497 - val_loss: 0.1478
# Epoch 18/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1487
# Epoch 18: val_loss improved from 0.14777 to 0.14735, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1487 - val_loss: 0.1473
# Epoch 19/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1488
# Epoch 19: val_loss improved from 0.14735 to 0.14669, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1488 - val_loss: 0.1467
# Epoch 20/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1482
# Epoch 20: val_loss improved from 0.14669 to 0.14636, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1482 - val_loss: 0.1464
# Epoch 21/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1478
# Epoch 21: val_loss improved from 0.14636 to 0.14574, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1478 - val_loss: 0.1457
# Epoch 22/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1468
# Epoch 22: val_loss improved from 0.14574 to 0.14538, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1468 - val_loss: 0.1454
# Epoch 23/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1463
# Epoch 23: val_loss improved from 0.14538 to 0.14441, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1463 - val_loss: 0.1444
# Epoch 24/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1455
# Epoch 24: val_loss improved from 0.14441 to 0.14363, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1455 - val_loss: 0.1436
# Epoch 25/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1448
# Epoch 25: val_loss improved from 0.14363 to 0.14285, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1448 - val_loss: 0.1429
# Epoch 26/30
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1439
# Epoch 26: val_loss improved from 0.14285 to 0.14240, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1439 - val_loss: 0.1424
# Epoch 27/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1436
# Epoch 27: val_loss improved from 0.14240 to 0.14187, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1436 - val_loss: 0.1419
# Epoch 28/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1432
# Epoch 28: val_loss improved from 0.14187 to 0.14148, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1432 - val_loss: 0.1415
# Epoch 29/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1429
# Epoch 29: val_loss improved from 0.14148 to 0.14118, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1429 - val_loss: 0.1412
# Epoch 30/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1425
# Epoch 30: val_loss improved from 0.14118 to 0.14081, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1425 - val_loss: 0.1408

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss',  # Metric to monitor
                              factor=0.5,  # Factor by which the learning rate will be reduced (new_lr = lr * factor)
                              patience=3,  # Number of epochs with no improvement after which learning rate will be reduced
                              min_lr=1e-6,  # Lower bound for the learning rate
                              verbose=1)  # Print message when the learning rate is reduced


# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
# Assuming x_train and x_test are your training and validation datasets
autoencoder.fit(x_train, x_train,  # For autoencoders, input and output are the same
                epochs=30,  # Number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),  # Validation data
                callbacks=[reduce_lr])  # Add the ReduceLROnPlateau callback
# Out:
# Epoch 1/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.4341 - val_loss: 0.2389 - learning_rate: 0.0010
# Epoch 2/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2272 - val_loss: 0.1941 - learning_rate: 0.0010
# Epoch 3/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1900 - val_loss: 0.1770 - learning_rate: 0.0010
# Epoch 4/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1763 - val_loss: 0.1686 - learning_rate: 0.0010
# Epoch 5/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.1678 - val_loss: 0.1605 - learning_rate: 0.0010
# Epoch 6/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1609 - val_loss: 0.1562 - learning_rate: 0.0010
# Epoch 7/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1570 - val_loss: 0.1531 - learning_rate: 0.0010
# Epoch 8/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1537 - val_loss: 0.1490 - learning_rate: 0.0010
# Epoch 9/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1498 - val_loss: 0.1463 - learning_rate: 0.0010
# Epoch 10/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1474 - val_loss: 0.1445 - learning_rate: 0.0010
# Epoch 11/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1457 - val_loss: 0.1435 - learning_rate: 0.0010
# Epoch 12/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1447 - val_loss: 0.1426 - learning_rate: 0.0010
# Epoch 13/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1443 - val_loss: 0.1421 - learning_rate: 0.0010
# Epoch 14/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.1432 - val_loss: 0.1414 - learning_rate: 0.0010
# Epoch 15/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1428 - val_loss: 0.1411 - learning_rate: 0.0010
# Epoch 16/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1424 - val_loss: 0.1407 - learning_rate: 0.0010
# Epoch 17/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1425 - val_loss: 0.1402 - learning_rate: 0.0010
# Epoch 18/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1415 - val_loss: 0.1398 - learning_rate: 0.0010
# Epoch 19/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1414 - val_loss: 0.1393 - learning_rate: 0.0010
# Epoch 20/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1406 - val_loss: 0.1386 - learning_rate: 0.0010
# Epoch 21/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1400 - val_loss: 0.1377 - learning_rate: 0.0010
# Epoch 22/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1389 - val_loss: 0.1369 - learning_rate: 0.0010
# Epoch 23/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1380 - val_loss: 0.1357 - learning_rate: 0.0010
# Epoch 24/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1370 - val_loss: 0.1351 - learning_rate: 0.0010
# Epoch 25/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1362 - val_loss: 0.1345 - learning_rate: 0.0010
# Epoch 26/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1354 - val_loss: 0.1339 - learning_rate: 0.0010
# Epoch 27/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1352 - val_loss: 0.1334 - learning_rate: 0.0010
# Epoch 28/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.1349 - val_loss: 0.1330 - learning_rate: 0.0010
# Epoch 29/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1347 - val_loss: 0.1328 - learning_rate: 0.0010
# Epoch 30/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1339 - val_loss: 0.1325 - learning_rate: 0.0010

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TerminateOnNaN, ReduceLROnPlateau

# EarlyStopping callback to stop training if validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# ModelCheckpoint callback to save the best model based on validation loss
checkpoint = ModelCheckpoint(filepath='autoencoder_best.keras', monitor='val_loss', save_best_only=True, verbose=1)

# TerminateOnNaN callback to stop training if the loss becomes NaN
terminate_on_nan = TerminateOnNaN()

# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5,   patience=3, min_lr=1e-6, verbose=1)

# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Training with multiple callbacks
autoencoder.fit(x_train, x_train,
                epochs=30,  # You can set a high number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[reduce_lr, early_stopping, checkpoint, terminate_on_nan])  # Using multiple callbacks
# Out:
# Epoch 1/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4351
# Epoch 1: val_loss improved from inf to 0.24041, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.4326 - val_loss: 0.2404 - learning_rate: 0.0010
# Epoch 2/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2276
# Epoch 2: val_loss improved from 0.24041 to 0.19593, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2273 - val_loss: 0.1959 - learning_rate: 0.0010
# Epoch 3/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1929
# Epoch 3: val_loss improved from 0.19593 to 0.17989, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1928 - val_loss: 0.1799 - learning_rate: 0.0010
# Epoch 4/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1789
# Epoch 4: val_loss improved from 0.17989 to 0.17106, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1789 - val_loss: 0.1711 - learning_rate: 0.0010
# Epoch 5/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1718
# Epoch 5: val_loss improved from 0.17106 to 0.16711, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1718 - val_loss: 0.1671 - learning_rate: 0.0010
# Epoch 6/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1671
# Epoch 6: val_loss improved from 0.16711 to 0.16245, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1671 - val_loss: 0.1624 - learning_rate: 0.0010
# Epoch 7/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1634
# Epoch 7: val_loss improved from 0.16245 to 0.16046, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.1634 - val_loss: 0.1605 - learning_rate: 0.0010
# Epoch 8/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1616
# Epoch 8: val_loss improved from 0.16046 to 0.15806, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1616 - val_loss: 0.1581 - learning_rate: 0.0010
# Epoch 9/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1589
# Epoch 9: val_loss improved from 0.15806 to 0.15598, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1589 - val_loss: 0.1560 - learning_rate: 0.0010
# Epoch 10/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1571
# Epoch 10: val_loss improved from 0.15598 to 0.15471, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1571 - val_loss: 0.1547 - learning_rate: 0.0010
# Epoch 11/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1562
# Epoch 11: val_loss improved from 0.15471 to 0.15393, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.1562 - val_loss: 0.1539 - learning_rate: 0.0010
# Epoch 12/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1552
# Epoch 12: val_loss improved from 0.15393 to 0.15324, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1552 - val_loss: 0.1532 - learning_rate: 0.0010
# Epoch 13/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1542
# Epoch 13: val_loss improved from 0.15324 to 0.15168, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1542 - val_loss: 0.1517 - learning_rate: 0.0010
# Epoch 14/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1526
# Epoch 14: val_loss improved from 0.15168 to 0.14996, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1525 - val_loss: 0.1500 - learning_rate: 0.0010
# Epoch 15/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1507
# Epoch 15: val_loss improved from 0.14996 to 0.14812, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1507 - val_loss: 0.1481 - learning_rate: 0.0010
# Epoch 16/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1489
# Epoch 16: val_loss improved from 0.14812 to 0.14642, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1489 - val_loss: 0.1464 - learning_rate: 0.0010
# Epoch 17/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1475
# Epoch 17: val_loss improved from 0.14642 to 0.14318, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1475 - val_loss: 0.1432 - learning_rate: 0.0010
# Epoch 18/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1440
# Epoch 18: val_loss improved from 0.14318 to 0.14065, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1440 - val_loss: 0.1407 - learning_rate: 0.0010
# Epoch 19/30
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1415
# Epoch 19: val_loss improved from 0.14065 to 0.13904, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.1415 - val_loss: 0.1390 - learning_rate: 0.0010
# Epoch 20/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1404
# Epoch 20: val_loss improved from 0.13904 to 0.13841, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1404 - val_loss: 0.1384 - learning_rate: 0.0010
# Epoch 21/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1398
# Epoch 21: val_loss improved from 0.13841 to 0.13792, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1398 - val_loss: 0.1379 - learning_rate: 0.0010
# Epoch 22/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1393
# Epoch 22: val_loss improved from 0.13792 to 0.13733, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1393 - val_loss: 0.1373 - learning_rate: 0.0010
# Epoch 23/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1389
# Epoch 23: val_loss improved from 0.13733 to 0.13716, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1389 - val_loss: 0.1372 - learning_rate: 0.0010
# Epoch 24/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1386
# Epoch 24: val_loss improved from 0.13716 to 0.13706, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1386 - val_loss: 0.1371 - learning_rate: 0.0010
# Epoch 25/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1381
# Epoch 25: val_loss improved from 0.13706 to 0.13654, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1381 - val_loss: 0.1365 - learning_rate: 0.0010
# Epoch 26/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1376
# Epoch 26: val_loss improved from 0.13654 to 0.13637, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1377 - val_loss: 0.1364 - learning_rate: 0.0010
# Epoch 27/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1375
# Epoch 27: val_loss improved from 0.13637 to 0.13590, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1375 - val_loss: 0.1359 - learning_rate: 0.0010
# Epoch 28/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1374
# Epoch 28: val_loss did not improve from 0.13590
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1374 - val_loss: 0.1359 - learning_rate: 0.0010
# Epoch 29/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1372
# Epoch 29: val_loss improved from 0.13590 to 0.13543, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1372 - val_loss: 0.1354 - learning_rate: 0.0010
# Epoch 30/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1370
# Epoch 30: val_loss improved from 0.13543 to 0.13522, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1370 - val_loss: 0.1352 - learning_rate: 0.0010

# %%
from tensorflow.keras.models import load_model

# Load the entire model
best_autoencoder = load_model('autoencoder_best.keras')

# Let's look at the encoded representations
encoded_data = best_autoencoder.predict(x_test)
print(encoded_data)
print(encoded_data.shape)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# [[1.9807577e-15 1.5152339e-14 3.9891061e-13 ... 7.5100016e-15
#   6.1764503e-15 2.0991466e-16]
#  [1.0935202e-10 4.1839920e-10 2.3050595e-10 ... 1.8456821e-10
#   2.4213373e-10 2.5670152e-10]
#  [1.9581055e-16 1.8931988e-14 5.0116181e-16 ... 3.8398740e-16
#   8.2408886e-15 2.9677345e-15]
#  ...
#  [9.4068260e-16 6.2475350e-16 3.9129981e-14 ... 9.5997547e-15
#   1.2012526e-15 2.2314454e-17]
#  [2.7297345e-10 8.1712576e-10 3.1884095e-09 ... 1.1436131e-09
#   4.0451742e-10 3.5425576e-11]
#  [6.7035170e-14 3.0569222e-15 1.2275606e-14 ... 1.4145321e-13
#   1.8933355e-15 2.8076197e-15]]
# (10000, 784)
